# %% [markdown]
# # Notebook for analyzing flights data

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/blue/bsc4452/share/Class_Files/data/flights.1M.csv'

df = pd.read_csv(data_path)
df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2019        1      1           4          5  2019-01-04
# 1       2019        1      1           4          5  2019-01-04
# 2       2019        1      1           4          5  2019-01-04
# 3       2019        1      1           4          5  2019-01-04
# 4       2019        1      1           4          5  2019-01-04
# ...      ...      ...    ...         ...        ...         ...
# 999994  2019        1      2           1          5  2019-02-01
# 999995  2019        1      2           1          5  2019-02-01
# 999996  2019        1      2           1          5  2019-02-01
# 999997  2019        1      2           1          5  2019-02-01
# 999998  2019        1      2           1          5  2019-02-01
#
#        Reporting_Airline Tail_Number  Flight_Number_Reporting_Airline Origin  \
# 0                     OO      N945SW                             5657    SBP
# 1                     OO      N932SW                             5658    IAH
# 2                     OO      N932SW                             5658    SGF
# 3                     OO      N916SW                             5659    ISN
# 4                     OO      N107SY                             5660    MKE
# ...                  ...         ...                              ...    ...
# 999994                WN      N8606C                             2089    BWI
# 999995                WN      N8723Q                             1177    BWI
# 999996                WN      N8649A                             1387    BWI
# 999997                WN      N786SW                             2285    BWI
# 999998                WN      N726SW                              901    BWI
#
#         ... CancellationCode Diverted AirTime Flights Distance  CarrierDelay  \
# 0       ...              NaN      0.0    37.0     1.0    190.0           NaN
# 1       ...              NaN      0.0    76.0     1.0    438.0           NaN
# 2       ...              NaN      0.0    88.0     1.0    513.0           NaN
# 3       ...              NaN      0.0    80.0     1.0    576.0           NaN
# 4       ...              NaN      0.0   127.0     1.0    896.0           NaN
# ...     ...              ...      ...     ...     ...      ...           ...
# 999994  ...              NaN      0.0   215.0     1.0   1565.0           0.0
# 999995  ...              NaN      0.0   112.0     1.0    738.0           0.0
# 999996  ...              NaN      0.0   118.0     1.0    738.0           0.0
# 999997  ...              NaN      0.0   112.0     1.0    738.0          16.0
# 999998  ...              NaN      0.0   124.0     1.0    842.0           0.0
#
#         WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 0                NaN       NaN            NaN                NaN
# 1                NaN       NaN            NaN                NaN
# 2                NaN       NaN            NaN                NaN
# 3                NaN       NaN            NaN                NaN
# 4                NaN       NaN            NaN                NaN
# ...              ...       ...            ...                ...
# 999994           0.0      50.0            0.0                0.0
# 999995          61.0      34.0            0.0               40.0
# 999996          48.0      64.0            0.0                0.0
# 999997           0.0       3.0            0.0              115.0
# 999998          76.0      43.0            0.0                0.0
#
# [999999 rows x 34 columns]

# %%
# Get a list off the columns in the df
columns = df.columns
print(columns)
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline',
#        'Origin', 'OriginCityName', 'OriginState', 'Dest', 'DestCityName',
#        'DestState', 'DepTime', 'DepDelay', 'DepDelayMinutes', 'DepDel15',
#        'ArrTime', 'ArrDelay', 'ArrDelayMinutes', 'ArrDel15', 'Cancelled',
#        'CancellationCode', 'Diverted', 'AirTime', 'Flights', 'Distance',
#        'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay',
#        'LateAircraftDelay'],
#       dtype='object')

# %%
# Using the Year and Month columns, calculate the number of flights each month
# Hint: Use the groupby() function
flights_per_month = df.groupby(['Year', 'Month']).size()
print(flights_per_month)
# Out:
# Year  Month
# 2019  1        583985
#       2        416014
# dtype: int64

# %%
# Using the Year, Month and ArrDelay columns, calculate the number of flights delayed per month
# Hint: Use the groupby() function  
# Hint: Use the sum() function
delayed_flights_per_month = df[df['ArrDelay'] > 0].groupby(['Year', 'Month']).size()
print(delayed_flights_per_month)
# Out:
# Year  Month
# 2019  1        193194
#       2        160626
# dtype: int64
