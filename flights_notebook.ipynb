# %% [markdown]
# # Notebook for analyzing flights data

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/blue/bsc4452/share/Class_Files/data/flights.1K.csv'

df = pd.read_csv(data_path)
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        1      1           4          5  2019-01-04                OO
# 1  2019        1      1           4          5  2019-01-04                OO
# 2  2019        1      1           4          5  2019-01-04                OO
# 3  2019        1      1           4          5  2019-01-04                OO
# 4  2019        1      1           4          5  2019-01-04                OO
#
#   Tail_Number  Flight_Number_Reporting_Airline Origin  ... CancellationCode  \
# 0      N945SW                             5657    SBP  ...              NaN
# 1      N932SW                             5658    IAH  ...              NaN
# 2      N932SW                             5658    SGF  ...              NaN
# 3      N916SW                             5659    ISN  ...              NaN
# 4      N107SY                             5660    MKE  ...              NaN
#
# ...
